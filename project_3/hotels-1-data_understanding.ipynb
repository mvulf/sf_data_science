# %% [markdown]
# # PROJECT-3. EDA + Feature Engineering. Соревнование на Kaggle. Data Understanding

# %% [markdown]
# ## 0. Описание кейса и постановка задачи
#
# Представьте, что вы работаете дата-сайентистом в компании Booking. Одна из проблем компании — это нечестные отели, которые накручивают себе рейтинг. Одним из способов обнаружения таких отелей является построение модели, *которая предсказывает рейтинг отеля*. Если предсказания модели сильно отличаются от фактического результата, то, возможно, отель ведёт себя нечестно, и его стоит проверить.
#
# Вы будете работать с датасетом, в котором содержатся сведения о 515 000 отзывов на отели Европы. Модель, которую вы будете обучать, должна предсказывать рейтинг отеля по данным сайта Booking на основе имеющихся в датасете данных. Изученные нами навыки разведывательного анализа помогут улучшить модель.
#
# Первоначальная версия датасета содержит 17 полей со следующей информацией:
#
# - hotel_address — адрес отеля;
# - review_date — дата, когда рецензент разместил соответствующий отзыв;
# - average_score — средний балл отеля, рассчитанный на основе последнего комментария за последний год;
# - hotel_name — название отеля;
# - reviewer_nationality — страна рецензента;
# - negative_review — отрицательный отзыв, который рецензент дал отелю;
# - review_total_negative_word_counts — общее количество слов в отрицательном отзыв;
# - positive_review — положительный отзыв, который рецензент дал отелю;
# - review_total_positive_word_counts — общее количество слов в положительном отзыве.
# - reviewer_score — оценка, которую рецензент поставил отелю на основе своего опыта;
# - total_number_of_reviews_reviewer_has_given — количество отзывов, которые рецензенты дали в прошлом;
# - total_number_of_reviews — общее количество действительных отзывов об отеле;
# - tags — теги, которые рецензент дал отелю;
# - days_since_review — количество дней между датой проверки и датой очистки;
# - additional_number_of_scoring — есть также некоторые гости, которые просто поставили оценку сервису, но не оставили отзыв. Это число указывает, сколько там действительных оценок без проверки.
# - lat — географическая широта отеля;
# - lng — географическая долгота отеля.

# %% [markdown]
# ## 1. Подготовка к работе

# %% [markdown]
# ### 1.1. Импорт библиотек

# %%
import pandas as pd
import numpy as np

# Библиотеки визуализации
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# Установка параметров визуализации
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 300
sns.set_theme(style='darkgrid')

# Собственный модуль обработки данных
from eda import *

# %% [markdown]
# ### 1.2. Загрузка данных

# %%
# Загрузим данные для обучения
hotels = pd.read_csv('input/hotels_train.csv')
hotels.head(3)
# Out:
#                                        hotel_address  \
# 0  Stratton Street Mayfair Westminster Borough Lo...
# 1  130 134 Southampton Row Camden London WC1B 5AF...
# 2   151 bis Rue de Rennes 6th arr 75006 Paris France
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           581   2/19/2016            8.4
# 1                           299   1/12/2017            8.3
# 2                            32  10/18/2016            8.9
#
#                           hotel_name reviewer_nationality  \
# 0                 The May Fair Hotel      United Kingdom
# 1    Mercure London Bloomsbury Hotel      United Kingdom
# 2  Legend Saint Germain by Elegancia               China
#
#        negative_review  review_total_negative_word_counts  \
# 0             Leaving                                   3
# 1       poor breakfast                                  3
# 2   No kettle in room                                   6
#
#    total_number_of_reviews      positive_review  \
# 0                     1994   Staff were amazing
# 1                     1361             location
# 2                      406          No Positive
#
#    review_total_positive_word_counts  \
# 0                                  4
# 1                                  2
# 2                                  0
#
#    total_number_of_reviews_reviewer_has_given  reviewer_score  \
# 0                                           7            10.0
# 1                                          14             6.3
# 2                                          14             7.5
#
#                                                 tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Studio Suite ...           531 day
# 1  [' Business trip ', ' Couple ', ' Standard Dou...           203 day
# 2  [' Leisure trip ', ' Solo traveler ', ' Modern...           289 day
#
#          lat       lng
# 0  51.507894 -0.143671
# 1  51.521009 -0.123097
# 2  48.845377  2.325643

# %%
# Загрузим тестовые данные
test = pd.read_csv('input/hotels_test.csv')
test.head(3)
# Out:
#                                        hotel_address  \
# 0                 Via Senigallia 6 20161 Milan Italy
# 1  Arlandaweg 10 Westpoort 1043 EW Amsterdam Neth...
# 2        Mallorca 251 Eixample 08008 Barcelona Spain
#
#    additional_number_of_scoring review_date  average_score  \
# 0                           904   7/21/2017            8.1
# 1                           612  12/12/2016            8.6
# 2                            46  11/26/2015            8.3
#
#                                    hotel_name reviewer_nationality  \
# 0                              Hotel Da Vinci      United Kingdom
# 1                           Urban Lodge Hotel             Belgium
# 2  Alexandra Barcelona A DoubleTree by Hilton              Sweden
#
#                                      negative_review  \
# 0   Would have appreciated a shop in the hotel th...
# 1        No tissue paper box was present at the room
# 2                                           Pillows
#
#    review_total_negative_word_counts  total_number_of_reviews  \
# 0                                 52                    16670
# 1                                 10                     5018
# 2                                  3                      351
#
#                                      positive_review  \
# 0   Hotel was great clean friendly staff free bre...
# 1                                        No Positive
# 2                         Nice welcoming and service
#
#    review_total_positive_word_counts  \
# 0                                 62
# 1                                  0
# 2                                  5
#
#    total_number_of_reviews_reviewer_has_given  \
# 0                                           1
# 1                                           7
# 2                                          15
#
#                                                 tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Double Room '...           13 days
# 1  [' Leisure trip ', ' Group ', ' Triple Room ',...           234 day
# 2  [' Business trip ', ' Solo traveler ', ' Twin ...           616 day
#
#          lat       lng
# 0  45.533137  9.171102
# 1  52.385649  4.834443
# 2  41.393192  2.161520

# %% [markdown]
# ## 2. Понимание данных

# %%
print('Данные для обучения')
display(hotels.info())
print('Данные для тестирования')
display(test.info())
# Out:
# Данные для обучения
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386803 entries, 0 to 386802
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               386803 non-null  object
#  1   additional_number_of_scoring                386803 non-null  int64
#  2   review_date                                 386803 non-null  object
#  3   average_score                               386803 non-null  float64
#  4   hotel_name                                  386803 non-null  object
#  5   reviewer_nationality                        386803 non-null  object
#  6   negative_review                             386803 non-null  object
#  7   review_total_negative_word_counts           386803 non-null  int64
#  8   total_number_of_reviews                     386803 non-null  int64
#  9   positive_review                             386803 non-null  object
#  10  review_total_positive_word_counts           386803 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  386803 non-null  int64
#  12  reviewer_score                              386803 non-null  float64
#  13  tags                                        386803 non-null  object
#  14  days_since_review                           386803 non-null  object
#  15  lat                                         384355 non-null  float64
#  16  lng                                         384355 non-null  float64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 50.2+ MB
# None
# Данные для тестирования
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128935 entries, 0 to 128934
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   hotel_address                               128935 non-null  object
#  1   additional_number_of_scoring                128935 non-null  int64
#  2   review_date                                 128935 non-null  object
#  3   average_score                               128935 non-null  float64
#  4   hotel_name                                  128935 non-null  object
#  5   reviewer_nationality                        128935 non-null  object
#  6   negative_review                             128935 non-null  object
#  7   review_total_negative_word_counts           128935 non-null  int64
#  8   total_number_of_reviews                     128935 non-null  int64
#  9   positive_review                             128935 non-null  object
#  10  review_total_positive_word_counts           128935 non-null  int64
#  11  total_number_of_reviews_reviewer_has_given  128935 non-null  int64
#  12  tags                                        128935 non-null  object
#  13  days_since_review                           128935 non-null  object
#  14  lat                                         128115 non-null  float64
#  15  lng                                         128115 non-null  float64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 15.7+ MB
# None

# %% [markdown]
# Явные пропуски содержатся в колонках долготы и широты местоположения отеля (lat & lng).
# В числовом формате данные хранятся в 9 из 16 столбцах.

# %% [markdown]
# #### **hotel_address** и **hotel_name**

# %% [markdown]
# Оценим количество отелей в данных

# %%
print(f"Количество уникальных адресов отелей: {hotels['hotel_address'].nunique()}")
print(f"Количество уникальных имён отелей: {hotels['hotel_name'].nunique()}")
# Out:
# Количество уникальных адресов отелей: 1493
# Количество уникальных имён отелей: 1492

# %% [markdown]
# Похоже, что на одно название отеля приходится 2 адреса. Определим, что это за отель.

# %%
# Сгруппируем по именам отелей и определим уникальные адреса
hotels_addresses = hotels.groupby(by='hotel_name')['hotel_address'].nunique()
# Проанализируем количество уникальных адресов для каждого отеля
n_hotels_addresses = hotels_addresses.sort_values(ascending=False)
n_hotels_addresses
# Out:
# hotel_name
# Hotel Regina                                    3
# 11 Cadogan Gardens                              1
# Mercure Paris Gare Montparnasse                 1
# Mercure Paris Pigalle Sacre Coeur               1
# Mercure Paris Opera Louvre                      1
#                                                ..
# Ham Yard Hotel                                  1
# Hallmark Hotel London Chigwell Prince Regent    1
# HCC St Moritz                                   1
# HCC Regente                                     1
# pentahotel Vienna                               1
# Name: hotel_address, Length: 1492, dtype: int64

# %% [markdown]
# Таким образом, мы видим, что только у "Hotel Regina" имеется несколько уникальных адресов. Посмотрим на эти адреса

# %%
# Извлечём название отеля с несколькими адресами
frequent_hotel = n_hotels_addresses.index[0]

# Проанализируем адреса этого отеля
frequent_hotel_addresses = list(hotels[hotels['hotel_name'] == frequent_hotel]\
    ['hotel_address'].unique())
print(f'Адреса отеля {frequent_hotel}: {frequent_hotel_addresses}')
# Out:
# Адреса отеля Hotel Regina: ['Bergara 2 4 Eixample 08002 Barcelona Spain', 'Rooseveltplatz 15 09 Alsergrund 1090 Vienna Austria', 'Via Cesare Correnti 13 Milan City Center 20123 Milan Italy']

# %% [markdown]
# У "Hotel Regina" есть 3 адреса в различных странах: Испания, Италия и Австрия.
#
# При этом число уникальных названий отелей и уникальных адресов отличается только на 1 в пользу адреса. Можно предположить, что есть дублирование адреса. Проверим.

# %%
# Сгруппируем по адресам отелей и определим уникальные имена
hotels_names = hotels.groupby(by='hotel_address')['hotel_name'].nunique()
# Проанализируем количество уникальных имён для каждого адреса
n_hotels_names = hotels_names.sort_values(ascending=False)
n_hotels_names.head(5)
# Out:
# hotel_address
# 8 Northumberland Avenue Westminster Borough London WC2N 5BY United Kingdom    2
# Hernalser Hauptstra e 105 17 Hernals 1170 Vienna Austria                      1
# Hoffingergasse 26 28 12 Meidling 1120 Vienna Austria                          1
# Hobbemakade 50 Oud Zuid 1071 XL Amsterdam Netherlands                         1
# Hintschiggasse 1 10 Favoriten 1100 Vienna Austria                             1
# Name: hotel_name, dtype: int64

# %% [markdown]
# Таким образом, есть адрес, по которому зарегистрировано 2 отеля. Посмотрим на названия отелей.

# %%
# Извлечём адрес с несколькими отелями
frequent_address = n_hotels_names.index[0]

# Проанализируем отели одного адреса
frequent_address_hotels = list(hotels[hotels['hotel_address'] ==\
    frequent_address]['hotel_name'].unique())
print(f'Названия отелей по адресу {frequent_address}: {frequent_address_hotels}')
# Out:
# Названия отелей по адресу 8 Northumberland Avenue Westminster Borough London WC2N 5BY United Kingdom: ['The Grand at Trafalgar Square', 'Club Quarters Hotel Trafalgar Square']

# %% [markdown]
# Проверка с помощью онлайн-карт google подтвердила, что по одному адресу зарегистрированы 2 отеля.

# %% [markdown]
# Посмотрим на частоту отзывов отелей:

# %%
display(hotels.groupby(by=['hotel_name','hotel_address'])['review_date']\
    .count().sort_values(ascending=True).reset_index().head(1200))
display(hotels.groupby(by=['hotel_name','hotel_address'])['review_date']\
    .count().sort_values(ascending=False).reset_index().head(300))
# Out:
#                                             hotel_name  \
# 0                        Mercure Paris Porte d Orleans
# 1                                         Hotel Wagner
# 2                                  Hotel Gallitzinberg
# 3               Renaissance Paris Republique Hotel Spa
# 4                         Ibis Styles Milano Palmanova
# ...                                                ...
# 1195  LaGare Hotel Milano Centrale MGallery by Sofitel
# 1196                          Park International Hotel
# 1197                            H10 Metropolitan 4 Sup
# 1198                          Novotel Paris Les Halles
# 1199                         Bianca Maria Palace Hotel
#
#                                           hotel_address  review_date
# 0                13 Rue Fran ois Ory 92120 Paris France            5
# 1     Via M Buonarroti 13 Fiera Milano City 20149 Mi...            6
# 2     Johann Staud Stra e 32 16 Ottakring 1160 Vienn...            6
# 3     40 Rue Rene Boulanger 10th arr 75010 Paris France            7
# 4                   Via Palmanova 153 20132 Milan Italy            7
# ...                                                 ...          ...
# 1195  Via Gian Battista Pirelli 20 Central Station 2...          381
# 1196  117 129 Cromwell Road Kensington and Chelsea L...          382
# 1197  Rambla Catalunya 7 9 Eixample 08007 Barcelona ...          382
# 1198  8 Place Marguerite de Navarre 1st arr 75001 Pa...          383
# 1199  Viale Bianca Maria 4 Milan City Center 20129 M...          383
#
# [1200 rows x 3 columns]
#                                             hotel_name  \
# 0           Britannia International Hotel Canary Wharf
# 1                                  Strand Palace Hotel
# 2                 Park Plaza Westminster Bridge London
# 3               Copthorne Tara Hotel London Kensington
# 4    DoubleTree by Hilton Hotel London Tower of London
# ..                                                 ...
# 295                               Great St Helen Hotel
# 296                           Park International Hotel
# 297                             H10 Metropolitan 4 Sup
# 298                  Catalonia Passeig de Gr cia 4 Sup
# 299                   Golden Tulip Amsterdam Riverside
#
#                                          hotel_address  review_date
# 0    163 Marsh Wall Docklands Tower Hamlets London ...         3587
# 1    372 Strand Westminster Borough London WC2R 0JJ...         3206
# 2    Westminster Bridge Road Lambeth London SE1 7UT...         3095
# 3    Scarsdale Place Kensington Kensington and Chel...         2688
# 4    7 Pepys Street City of London London EC3N 4AF ...         2379
# ..                                                 ...          ...
# 295  36 Great st Helens City of London London EC3A ...          383
# 296  117 129 Cromwell Road Kensington and Chelsea L...          382
# 297  Rambla Catalunya 7 9 Eixample 08007 Barcelona ...          382
# 298  Gran Via de les Corts Catalanes 644 Eixample 0...          381
# 299  Provincialeweg 38 Zuidoost 1108 AB Amsterdam N...          381
#
# [300 rows x 3 columns]

# %% [markdown]
# **Note**:
# - В дальнейшем может потребоваться уменьшить количество уникальных названий отеля, введя категорию other_name для остальных названий. *Например, при сокращении до 300 уникальных имён отелей по количеству отзывов.*
# - При необходимости, к имени 'Hotel Regina' можно добавить страну расположения отеля.
# - При генерации признаков из полного адреса можно извлечь город и страну расположения отеля.

# %% [markdown]
# #### **additional_number_of_scoring**

# %% [markdown]
# Согласно представленному выше описанию получается, что это общее количество оценок без отзывов, которое выставлено отелю. Значит у разных отзывов одного отеля должны быть одинаковые значения. Проверим это.

# %%
display(hotels['additional_number_of_scoring'].describe())

addit_n_scoring = hotels.groupby(by=['hotel_name', 'hotel_address'])\
    ['additional_number_of_scoring'].median().reset_index()
box_hist_plot(addit_n_scoring, 'additional_number_of_scoring',\
    'Распределение количества оценок без отзывов')
# Out:
# count    386803.000000
# mean        498.246536
# std         500.258012
# min           1.000000
# 25%         169.000000
# 50%         342.000000
# 75%         660.000000
# max        2682.000000
# Name: additional_number_of_scoring, dtype: float64

# %%
grouped_by_name = hotels.groupby(by='hotel_name')
scoring_number_difference = grouped_by_name['additional_number_of_scoring']\
    .max() - grouped_by_name['additional_number_of_scoring'].min()
scoring_number_difference.sort_values(ascending=False)
# Out:
# hotel_name
# Hotel Regina                                    311
# 11 Cadogan Gardens                                0
# Mercure Paris Gare Montparnasse                   0
# Mercure Paris Pigalle Sacre Coeur                 0
# Mercure Paris Opera Louvre                        0
#                                                ...
# Ham Yard Hotel                                    0
# Hallmark Hotel London Chigwell Prince Regent      0
# HCC St Moritz                                     0
# HCC Regente                                       0
# pentahotel Vienna                                 0
# Name: additional_number_of_scoring, Length: 1492, dtype: int64

# %% [markdown]
# Видим, что разница в количестве отзывов есть только у отеля Регина. Проверим, что для трёх отелей разных адресов три разные цифры количества оценок, и при этом они не отличаются в рамках одного адреса

# %%
regina_grouped_by_name = hotels[hotels['hotel_name'] == 'Hotel Regina']\
    .groupby('hotel_address')

regina_median_scoring_number = regina_grouped_by_name\
    ['additional_number_of_scoring'].median()
print('Количество оценок без отзывов для отеля Регина по разным адресам')
display(regina_median_scoring_number.sort_values(ascending=False))

regina_scoring_number_difference = regina_grouped_by_name\
    ['additional_number_of_scoring'].max() -\
        regina_grouped_by_name['additional_number_of_scoring'].min()
print('Разница в количестве оценок в рамках одного адреса')
display(regina_scoring_number_difference.sort_values(ascending=False))
# Out:
# Количество оценок без отзывов для отеля Регина по разным адресам
# hotel_address
# Bergara 2 4 Eixample 08002 Barcelona Spain                    334.0
# Rooseveltplatz 15 09 Alsergrund 1090 Vienna Austria           165.0
# Via Cesare Correnti 13 Milan City Center 20123 Milan Italy     23.0
# Name: additional_number_of_scoring, dtype: float64
# Разница в количестве оценок в рамках одного адреса
# hotel_address
# Bergara 2 4 Eixample 08002 Barcelona Spain                    0
# Rooseveltplatz 15 09 Alsergrund 1090 Vienna Austria           0
# Via Cesare Correnti 13 Milan City Center 20123 Milan Italy    0
# Name: additional_number_of_scoring, dtype: int64

# %% [markdown]
# **Note**: Таким образом, мы убедились в том, что статистика для Отелей Регина разных стран ведётся отдельно.

# %% [markdown]
# #### **review_date** - edited

# %% [markdown]
# Приведём к формату datetime

# %%
hotels['review_date'] = pd.to_datetime(hotels['review_date'])
hotels['review_date'].describe(datetime_is_numeric=True)
# Out:
# count                           386803
# mean     2016-08-13 14:41:18.712936704
# min                2015-08-04 00:00:00
# 25%                2016-02-23 00:00:00
# 50%                2016-08-15 00:00:00
# 75%                2017-02-09 00:00:00
# max                2017-08-03 00:00:00
# Name: review_date, dtype: object

# %%
test['review_date'] = pd.to_datetime(hotels['review_date'])
test['review_date'].describe(datetime_is_numeric=True)
# Out:
# count                           128935
# mean     2016-08-13 16:21:41.567456768
# min                2015-08-04 00:00:00
# 25%                2016-02-23 00:00:00
# 50%                2016-08-16 00:00:00
# 75%                2017-02-11 00:00:00
# max                2017-08-03 00:00:00
# Name: review_date, dtype: object

# %% [markdown]
# Таким образом, перед нами выгрузка отзывов за 2 года с 4 августа 2015 года по 3 августа 2017 года.

# %% [markdown]
# **Note:**
# - В дальнейшем из даты можно извлечь сезонность

# %% [markdown]
# #### **average_score**

# %% [markdown]
# Данный признак представляет собой среднюю оценку отеля за последний год. Проанализируем его

# %%
average_score_plot = box_hist_plot(hotels, 'average_score',\
    'Распределение средней оценки', hist_yscale='log')
display(hotels['average_score'].describe())
average_score_plot
# Out:
# count    386803.000000
# mean          8.397231
# std           0.547881
# min           5.200000
# 25%           8.100000
# 50%           8.400000
# 75%           8.800000
# max           9.800000
# Name: average_score, dtype: float64

# %% [markdown]
# Наблюдаем левосторонние гипотетические выбросы, а также отели с очень высокой оценкой

# %% [markdown]
# Оценим визуально взаимосвязь средней оценки и оценки в отзыве

# %%
p = sns.jointplot(y='reviewer_score', x='average_score', data=hotels,\
    kind='reg')
p.fig.suptitle('Взаимосвязь оценки рецензента и средней оценки отеля');
p.fig.subplots_adjust(top=0.95)

# %% [markdown]
# **Note**:
# - Имеет смысл ввести порядковый категориальный признак, чтобы отличать плохие, средние, хорошие и очень хорошие отели
# - Видим положительную корреляцию выставляемой оценки и средней оценки, что ожидаемо

# %% [markdown]
# #### **reviewer_nationality**

# %%
print('Представленные в датасете национальности:')
display(hotels['reviewer_nationality'].value_counts())
# Out:
# Представленные в датасете национальности:
#  United Kingdom               184033
#  United States of America      26541
#  Australia                     16239
#  Ireland                       11126
#  United Arab Emirates           7617
#                                ...
#  Cook Islands                      1
#  Guinea                            1
#  Comoros                           1
#  Anguilla                          1
#  Grenada                           1
# Name: reviewer_nationality, Length: 225, dtype: int64

# %% [markdown]
# **Note**:
# - Возможно, имеет смысл сопоставить национальность рецензента и страну, где находится отель. И выделить признак международного путешествия рецензента.
# - Можно проверить гипотезу влияния типа поездки - международная или национальная на оставляемый рейтинг.
# - Также можно уменьшить количество рассматриваемых национальностей, введя категорию 'other'
# - Скрытые пропуски не обнаружены

# %% [markdown]
# #### **tags** -> **splitted_tags**

# %% [markdown]
# Извлечём теги и сохраним их в множество, тем самым получим уникальные теги.

# %%
# Извлечём сырые теги из соответствующей колонки 
# и сохраним в виде списка
hotels['splitted_tags'] = hotels['tags'].str.findall(r"'[\w\s]+'")
test['splitted_tags'] = test['tags'].str.findall(r"'[\w\s]+'")

# Преобразуем списки, удалив одинарные кавычки и внешние пробелы
hotels['splitted_tags'] = hotels['splitted_tags'].\
    apply(lambda x: [y[1:-1].strip() for y in x])
test['splitted_tags'] = test['splitted_tags'].\
    apply(lambda x: [y[1:-1].strip() for y in x])

# Создадим множество уникальных тегов
unique_tags = set()

# Функия извлечения тегов в множество
def get_tags(tags):
    unique_tags.update(tags)
    return True

hotels['splitted_tags'].apply(get_tags)
print('Количество уникальных тегов:', len(unique_tags))
# Out:
# Количество уникальных тегов: 2368

# %%
print('Минимальное количество тегов в отзыве:', hotels['splitted_tags']\
    .apply(len).min())
# Out:
# Минимальное количество тегов в отзыве: 1

# %% [markdown]
# Пропуски тегов отсутствуют

# %% [markdown]
# Оценим популярность тегов

# %%
from collections import Counter

# Создадим пустой список, который будем заполнять тегами 
# из датафрейма 
tags_list = []
def extend_tags(tags):
    tags_list.extend(tags)
hotels['splitted_tags'].apply(extend_tags)

# Посчитаем количество применений тегов
# и представим в виде Series
cnt = Counter(tags_list)
tag_cnt = pd.Series(dict(cnt))

# Выведем отсортированный Series
tag_cnt.sort_values(ascending=False).head(28)
# Out:
# Leisure trip                      313593
# Submitted from a mobile device    230778
# Couple                            189212
# Stayed 1 night                    145373
# Stayed 2 nights                   100263
# Solo traveler                      81235
# Stayed 3 nights                    72000
# Business trip                      61989
# Group                              49088
# Family with young children         45836
# Stayed 4 nights                    35748
# Double Room                        26386
# Standard Double Room               24151
# Superior Double Room               23550
# Family with older children         19802
# Deluxe Double Room                 18623
# Double or Twin Room                16824
# Stayed 5 nights                    15611
# Standard Double or Twin Room       13062
# Classic Double Room                12716
# Superior Double or Twin Room       10238
# 2 rooms                             9287
# Stayed 6 nights                     7399
# Standard Twin Room                  7325
# Single Room                         7227
# Twin Room                           6279
# Stayed 7 nights                     5549
# Executive Double Room               4763
# dtype: int64

# %% [markdown]
# **Note**:
# - В качестве отдельного признака можно создать количество присвоенных тегов
# - Имеет смысл выделить конкретные популярные теги
# - Из тегов можно выделить такую полезную информацию, как:
#     - отправлен ли отзыв с мобильного устройства;
#     - количество ночей, проведённых в гостинице;
#     - тип номера;
#     - тип путешествия;
#     - состав посетителей;

# %% [markdown]
# #### **negative_review** и **positive_review**

# %%
print('Частые негативные отзывы')
hotels['negative_review'].value_counts().sort_values(ascending=False).head(30)
# Out:
# Частые негативные отзывы
# No Negative            95907
#  Nothing               10737
#  Nothing                3154
#  nothing                1660
#  N A                     802
#  None                    737
#                          606
#  N a                     384
#  Breakfast               296
#  Small room              283
#  Location                281
#  All good                251
#  Everything              251
#  Nothing really          240
#  none                    223
#  nothing                 219
#  No complaints           201
#  Nil                     197
#  Nothing really          195
#  Price                   192
#  n a                     176
#  Nothing to dislike      159
#  Nothing at all          154
#  Nothing at all          139
#  Small rooms             135
#  None                    134
#  No complaints           129
#  All good                116
#  NA                      109
#  Expensive               105
# Name: negative_review, dtype: int64

# %%
print('Частые позитивные отзывы')
hotels['positive_review'].value_counts().sort_values(ascending=False).head(30)
# Out:
# Частые позитивные отзывы
# No Positive            26885
#  Location               6833
#  Everything             1697
#  location               1251
#  Nothing                 931
#  The location            830
#  Great location          809
#  Good location           690
#  Location                663
#  Breakfast               455
#  Everything              449
#  Friendly staff          385
#  Staff                   347
#  Excellent location      296
#  Great location          280
#  Location and staff      256
#  everything              233
#  Good location           214
#  Nothing                 170
#  nothing                 159
#  Comfy bed               158
#  The location            152
#  good location           151
#  The staff               151
#  the location            141
#  Location was good       140
#  Location was great      137
#  Location staff          136
#  Good breakfast          130
#                          128
# Name: positive_review, dtype: int64

# %% [markdown]
# **Note**:
# - Мы видим, что в отзывах большое количество слов, типа "No Positive/Negative", "Nothing", "Everything", "NA". Их можно представить в виде булевых признаков, типа "no_positive", "no_negative", "abs_positive", "abs_negative"
# - Из отзывов можно извлечь, чем клиент был доволен/недоволен, например: "location", "staff" и проверить гипотезу влияния этих категорий на оценку

# %% [markdown]
# #### **review_total_negative_word_counts** и **review_total_positive_word_counts**

# %%
display(hotels['review_total_negative_word_counts'].describe())
box_hist_plot(hotels, 'review_total_negative_word_counts',\
    'Распределение количества слов в отрицательном отзыве')
# Out:
# count    386803.000000
# mean         18.538988
# std          29.703369
# min           0.000000
# 25%           2.000000
# 50%           9.000000
# 75%          23.000000
# max         408.000000
# Name: review_total_negative_word_counts, dtype: float64

# %%
display(hotels['review_total_positive_word_counts'].describe())
box_hist_plot(hotels, 'review_total_positive_word_counts',\
    'Распределение количества слов в положительном отзыве')
# Out:
# count    386803.000000
# mean         17.776985
# std          21.726141
# min           0.000000
# 25%           5.000000
# 50%          11.000000
# 75%          22.000000
# max         395.000000
# Name: review_total_positive_word_counts, dtype: float64

# %% [markdown]
# **Note:**
# - Позитивные и негативные отзывы могут содержать до нескольких сот слов. При этом медианное количество слов порядка 10.
# - Необходимо проверить, влияет ли количество слов больше 20 на оценку.
# - При отсутствии слов можно отнести к категориям, выделенным выше по отзывам: no_positive, no_negative
# - Возможно, имеет смысл ввести категориальный признак: короткий, средний, длинный комментарий

# %% [markdown]
# #### TARGET: **reviewer_score**

# %%
display(hotels['reviewer_score'].describe())
box_hist_plot(hotels, 'reviewer_score', 'Распределение оценки рецензентов')
# Out:
# count    386803.000000
# mean          8.396906
# std           1.636090
# min           2.500000
# 25%           7.500000
# 50%           8.800000
# 75%           9.600000
# max          10.000000
# Name: reviewer_score, dtype: float64

# %% [markdown]
# На данном этапе не будем избавляться от аномальных значений целевого признкака.

# %% [markdown]
# #### **total_number_of_reviews_reviewer_has_given**

# %%
display(hotels['total_number_of_reviews_reviewer_has_given'].describe())
box_hist_plot(hotels, 'total_number_of_reviews_reviewer_has_given',\
    'Распределение количества отзывов, которые рецензенты дали в прошлом')
# Out:
# count    386803.00000
# mean          7.17725
# std          11.05442
# min           1.00000
# 25%           1.00000
# 50%           3.00000
# 75%           8.00000
# max         355.00000
# Name: total_number_of_reviews_reviewer_has_given, dtype: float64

# %% [markdown]
# Оценим зависимость оценки рецензента от количества данных отзывов.

# %%
p = sns.jointplot(y='reviewer_score',\
    x='total_number_of_reviews_reviewer_has_given', data=hotels, kind='reg')
p.fig.suptitle('Взаимосвязь оценки рецензента и количества оценок, '+\
    'оставленных рецензентом ранее');
p.fig.subplots_adjust(top=0.95) # Reduce plot to make room

# %% [markdown]
# **Note:**
# - Возможно, есть положительная корреляция между количеством отзывов, что рецензент давал ранее и рейтингом, им оставленным
# - Порядка четверти рецензентов оставляли единственный отзывов, и 3/4 рецензентов оставляли 8 и менее отзывов
# - Возможно, имеет смысл ввести порядковый категориальный признак - один, несколько, много отзывов.
# - Вероятно, люди, оставляющие один отзыв, как правило выставляют его негативным по сравнению с теми, кто имеет несколько отзывов

# %% [markdown]
# #### **total_number_of_reviews**
#
# Рассмотрим, как соотносится количество действительных отзывов отеля с количеством отзывов, представленных в датасете. Соотнесём количество отзывов с количеством оценок без отзывов

# %%
# Сгруппируем отели и рассмотрим количество отзывов, и количество оценок без отзывов
hotels_number_of_reviews = hotels.groupby(by=['hotel_name', 'hotel_address'])\
    .agg({
    'total_number_of_reviews': ['median','count'],
    'additional_number_of_scoring': 'median'
    })
hotels_number_of_reviews.columns = ['_'.join(col) for col\
    in hotels_number_of_reviews.columns]

# Переименуем колонки
hotels_number_of_reviews = hotels_number_of_reviews.rename(columns={
    'total_number_of_reviews_count': 'row-reviews count', 
    'total_number_of_reviews_median': 'total_number_of_reviews',
    'additional_number_of_scoring_median': 'additional_number_of_scoring'})

# Выделим процентные характеристики количества отзывов и оценок без отзывов
hotels_number_of_reviews['reviews_percentage_ratio'] =\
    hotels_number_of_reviews['row-reviews count']\
    /hotels_number_of_reviews['total_number_of_reviews']*100
hotels_number_of_reviews['additional_percentage_ratio'] =\
    hotels_number_of_reviews['additional_number_of_scoring']\
    /hotels_number_of_reviews['total_number_of_reviews']*100
    
print('Процентное соотношение отзывов, представленных в датафрейме, '+\
    'а также количества оценок без отзыва к общему количеству отзывов')
display(hotels_number_of_reviews[['reviews_percentage_ratio',\
    'additional_percentage_ratio']].describe())
# Out:
# Процентное соотношение отзывов, представленных в датафрейме, а также количества оценок без отзыва к общему количеству отзывов
#        reviews_percentage_ratio  additional_percentage_ratio
# count               1494.000000                  1494.000000
# mean                  19.689803                    14.773121
# std                    9.277361                     7.244809
# min                    3.381643                     2.040816
# 25%                   12.829634                     9.170629
# 50%                   17.126554                    12.881135
# 75%                   26.308422                    19.352924
# max                   55.944056                    39.705882

# %% [markdown]
# **Note**:
# - Таким образом, выгрузка отзывов не пропорциональна общему количеству отзывов у всех отелей.
# - Оценки без отзывов составляют малую часть общего количества оценок с отзывами. Возможно их соотношение влияет на предсказываемую оценку отеля, что дополнительно можно проверить.

# %% [markdown]
# #### **days_since_review** - edited
#
# Количество дней между оставлением отзыва и датой выгрузки. Приведём к числовому формату

# %%
hotels['days_since_review'] = hotels['days_since_review']\
    .apply(lambda x: int(x.split(' ')[0]))
test['days_since_review'] = test['days_since_review']\
    .apply(lambda x: int(x.split(' ')[0]))
hotels['days_since_review']
# Out:
# 0         531
# 1         203
# 2         289
# 3         681
# 4         516
#          ...
# 386798    106
# 386799    171
# 386800    543
# 386801     74
# 386802    363
# Name: days_since_review, Length: 386803, dtype: int64

# %%
display(hotels['days_since_review'].describe())
box_hist_plot(data=hotels, x='days_since_review',\
    title='Распределение по количеству прошедших дней с'+
    'момента оставления отзыва')
# Out:
# count    386803.000000
# mean        354.387978
# std         208.975174
# min           0.000000
# 25%         175.000000
# 50%         353.000000
# 75%         527.000000
# max         730.000000
# Name: days_since_review, dtype: float64

# %% [markdown]
# Проверим влияние количества дней с момента отправки отзыва на рейтинг

# %%
p = sns.jointplot(y='reviewer_score', x='days_since_review', data=hotels)
p.fig.suptitle('Взаимосвязь оценки рецензента и дней с момента'+\
    'оставления отзыва');
p.fig.subplots_adjust(top=0.95) # Reduce plot to make room

# %% [markdown]
# **Note:**
# - Отзывы примерно равномерно распределены по количеству дней с момента отправки
# - Отсутствует графическая взаимосвязь количества дней с момента отправки отзыва и выставленного рейтинга

# %% [markdown]
# #### **lat** и **lng**

# %% [markdown]
# Эти колонки содержат явные пропуски

# %%
lat_nans = hotels['lat'].isna().sum()/hotels.shape[0]*100
lng_nans = hotels['lng'].isna().sum()/hotels.shape[0]*100
print(f'Доля пропусков широты {round(lat_nans,2)}%, '+\
    f'долготы {round(lng_nans,2)}%')
# Out:
# Доля пропусков широты 0.63%, долготы 0.63%

# %% [markdown]
# Рассмотрим, что за отели имеют пропуски

# %%
hotels_without_lat = hotels[hotels['lat'].isna()].groupby(by=['hotel_name',\
    'hotel_address'])['hotel_name'].count()
display(hotels_without_lat)
print('Количество отелей без географических координат:',\
    hotels_without_lat.shape[0])
# Out:
# hotel_name                                        hotel_address
# Austria Trend Hotel Schloss Wilhelminenberg Wien  Savoyenstra e 2 16 Ottakring 1160 Vienna Austria               141
# City Hotel Deutschmeister                         Gr nentorgasse 30 09 Alsergrund 1090 Vienna Austria             63
# Cordial Theaterhotel Wien                         Josefst dter Stra e 22 08 Josefstadt 1080 Vienna Austria        40
# Derag Livinghotel Kaiser Franz Joseph Vienna      Sieveringer Stra e 4 19 D bling 1190 Vienna Austria            112
# Fleming s Selection Hotel Wien City               Josefst dter Stra e 10 12 08 Josefstadt 1080 Vienna Austria    496
# Holiday Inn Paris Montmartre                      23 Rue Damr mont 18th arr 75018 Paris France                    47
# Hotel Advance                                     Sep lveda 180 Eixample 08011 Barcelona Spain                    26
# Hotel Atlanta                                     W hringer Stra e 33 35 09 Alsergrund 1090 Vienna Austria       285
# Hotel City Central                                Taborstra e 8 A 02 Leopoldstadt 1020 Vienna Austria            421
# Hotel Daniel Vienna                               Landstra er G rtel 5 03 Landstra e 1030 Vienna Austria         182
# Hotel Park Villa                                  Hasenauerstra e 12 19 D bling 1190 Vienna Austria               44
# Hotel Pension Baron am Schottentor                W hringer Stra e 12 09 Alsergrund 1090 Vienna Austria          172
# Maison Albar Hotel Paris Op ra Diamond            4 rue de la P pini re 8th arr 75008 Paris France               224
# Mercure Paris Gare Montparnasse                   20 Rue De La Ga t 14th arr 75014 Paris France                   28
# NH Collection Barcelona Podium                    Bail n 4 6 Eixample 08010 Barcelona Spain                      113
# Renaissance Barcelona Hotel                       Pau Clar s 122 Eixample 08009 Barcelona Spain                   20
# Roomz Vienna                                      Paragonstra e 1 11 Simmering 1110 Vienna Austria                34
# Name: hotel_name, dtype: int64
# Количество отелей без географических координат: 17

# %% [markdown]
# Извлечём город и страну каждого из отелей

# %%
print('Посмотрим на последнее слово в адресе, '+\
    'которое должно представлять собой страну:')
hotels['hotel_address'].apply(lambda x: x.split()[-1]).unique()
# Out:
# Посмотрим на последнее слово в адресе, которое должно представлять собой страну:
# array(['Kingdom', 'France', 'Netherlands', 'Italy', 'Austria', 'Spain'],
#       dtype=object)

# %% [markdown]
# Видим, что Страны однословные, за исключением Великобритании. Учтём это.

# %%
# Учтём двусловность United Kingdom
hotels['hotel_country'] = hotels['hotel_address'].apply(lambda x:\
    x.split()[-1] if x.split()[-1] != 'Kingdom' else ' '.join(x.split()[-2:]))
print('Представленные в датасете страны:')
print(hotels['hotel_country'].unique())

# Модифицируем данные в test
test['hotel_country'] = test['hotel_address'].apply(lambda x: x.split()[-1] if\
    x.split()[-1] != 'Kingdom' else ' '.join(x.split()[-2:]))
# Out:
# Представленные в датасете страны:
# ['United Kingdom' 'France' 'Netherlands' 'Italy' 'Austria' 'Spain']

# %% [markdown]
# Извлечём города отелей

# %%
hotels[hotels['hotel_country'] == 'United Kingdom']['hotel_address'].unique()
# Out:
# array(['Stratton Street Mayfair Westminster Borough London W1J 8LT United Kingdom',
#        '130 134 Southampton Row Camden London WC1B 5AF United Kingdom',
#        '97 Cromwell Road Kensington and Chelsea London SW7 4DN United Kingdom',
#        '190 Queen s Gate Kensington and Chelsea London SW7 5EX United Kingdom',
#        'Holland Park Avenue Kensington and Chelsea London W11 4UL United Kingdom',
#        '34 44 Barkston Gardens Kensington and Chelsea London SW5 0EW United Kingdom',
#        '16 Sumner Place Kensington and Chelsea London SW7 3EG United Kingdom',
#        '1 Kings Cross Road Islington London WC1X 9HX United Kingdom',
#        'Wrights Lane Kensington and Chelsea London W8 5SP United Kingdom',
#        '59 Leinster Square Kensington and Chelsea London W2 4PS United Kingdom',
#        '20 Upper Ground Southwark London SE1 9PD United Kingdom',
#        '152 Cricklewood Broadway Cricklewood London NW2 3ED United Kingdom',
#        '10a Chestnut Plaza Westfield Stratford City Olympic Park Newham London E20 1GL United Kingdom',
#        '1 Addington Street Lambeth London SE1 7RY United Kingdom',
#        '88 Holland Road Kensington and Chelsea London W14 8BN United Kingdom',
#        '130 135 Minories City of London London EC3N 1NU United Kingdom',
#        '163 Marsh Wall Docklands Tower Hamlets London E14 9SJ United Kingdom',
#        '36 37 Lancaster Gate Westminster Borough London W2 3NA United Kingdom',
#        '65 73 Shaftesbury Avenue Westminster Borough London W1D 6EX United Kingdom',
#        '28 Ebury Street Westminster Borough London SW1W 0LU United Kingdom',
#        '97 Great Russell Street Bloomsbury Camden London WC1B 3LB United Kingdom',
#        'South Quay Marsh Wall Tower Hamlets London E14 9SH United Kingdom',
#        '64 76 Hendon Way London NW2 2NL United Kingdom',
#        '7 Pepys Street City of London London EC3N 4AF United Kingdom',
#        '2 The Avenue Ealing London W13 8PH United Kingdom',
#        '92 Southampton Row Camden London WC1B 4BH United Kingdom',
#        '1a Lexham Gardens Kensington and Chelsea London W8 5JJ United Kingdom',
#        '24 Ludgate Hill City of London London EC4M 7DR United Kingdom',
#        '33 37 Hogarth Road Kensington and Chelsea London SW5 0QQ United Kingdom',
#        '34 Norfolk Place Paddington Westminster Borough London W2 1QW United Kingdom',
#        '181 Cromwell Road Kensington and Chelsea London SW5 0SF United Kingdom',
#        '1 Shortlands Hammersmith and Fulham London W6 8DR United Kingdom',
#        'Westminster Bridge Road Lambeth London SE1 7UT United Kingdom',
#        '11 12 Poplar Mews Shepherd s Bush Hammersmith and Fulham London W12 7JS United Kingdom',
#        '54 Upper Berkeley Street Westminster Borough London W1H 7QR United Kingdom',
#        '30 Barkston Gardens Kensington and Chelsea London SW5 0EN United Kingdom',
#        '52 Chiswell Street City of London London EC1Y 4SD United Kingdom',
#        '354 Queenstown Road Battersea London SW8 4AE United Kingdom',
#        '419 437 Hackney Road London E2 8PP United Kingdom',
#        'Empire Way Wembley Brent London HA9 8DS United Kingdom',
#        '4 18 Harrington Gardens Kensington and Chelsea London SW7 4LH United Kingdom',
#        '12 Lancaster Gate Lancaster Gate Westminster Borough London W2 3LG United Kingdom',
#        'Bryanston Street Marble Arch Westminster Borough London W1H 7EH United Kingdom',
#        'Chelsea Harbour Hammersmith and Fulham London SW10 0XG United Kingdom',
#        '5 Curzon St Westminster Borough London W1J 5HL United Kingdom',
#        '173 185 Greenwich High Rd Greenwich London SE10 8JA United Kingdom',
#        '1 3 Queens Garden Westminster Borough London W2 3BA United Kingdom',
#        'Half Moon Street Westminster Borough London W1J 7BN United Kingdom',
#        '100 Shoreditch High Street Hackney London E1 6JQ United Kingdom',
#        'Portland Place Westminster Borough London W1B 1JA United Kingdom',
#        '31 34 Queen s Gate Kensington and Chelsea London SW7 5JA United Kingdom',
#        'Lakeside Way Brent London HA9 0BU United Kingdom',
#        '2 8 Hanger Lane Ealing Common London W5 3HN United Kingdom',
#        'Great Cumberland Place Westminster Borough London W1H 7DL United Kingdom',
#        'One Eastern Gateway Royal Victoria Dock Newham London E16 1FR United Kingdom',
#        'Aldwych Westminster Borough London WC2B 4DD United Kingdom',
#        'Westside Wimbledon Common Wimbledon London SW19 4UE United Kingdom',
#        '36 Great st Helens City of London London EC3A 6AP United Kingdom',
#        '225 High Street Kensington Kensington and Chelsea London W8 6SA United Kingdom',
#        '21 Piccadilly Westminster Borough London W1J 0BH United Kingdom',
#        '45 Prescot Street City of London London E1 8GP United Kingdom',
#        '2 Bridge Place Victoria Westminster Borough London SW1V 1QA United Kingdom',
#        '3 South Place City of London London EC2M 2AF United Kingdom',
#        '12 Folgate Street City of London London E1 6BX United Kingdom',
#        '129 Bayswater Road London W2 4RJ United Kingdom',
#        '30 Leinster Gardens Bayswater Westminster Borough London W2 3AN United Kingdom',
#        '23 Leinster Gardens Westminster Borough London W2 3AN United Kingdom',
#        'Fulham Road Stamford Bridge Hammersmith and Fulham London SW6 1HS United Kingdom',
#        '5 7 Princes Square Kensington and Chelsea London W2 4NP United Kingdom',
#        '61 Gloucester Road Kensington and Chelsea London SW7 4PE United Kingdom',
#        '2 24 Kensington High St Kensington and Chelsea London W8 4PT United Kingdom',
#        '28 Basil Street Kensington and Chelsea London SW3 1AS United Kingdom',
#        '1 Inverness Terrace Westminster Borough London W2 3JP United Kingdom',
#        '10 Berners Street Westminster Borough London W1T 3NP United Kingdom',
#        '43 51 Wembley Hill Road Brent London HA9 8AU United Kingdom',
#        '46 Blackfriars Road Southwark London SE1 8NZ United Kingdom',
#        '171 Knightsbridge Westminster Borough London SW7 1DW United Kingdom',
#        'Catherine Grove Greenwich Greenwich London SE10 8BB United Kingdom',
#        'Plaza Parade Camden London NW6 5RP United Kingdom',
#        '173 Gloucester Place Westminster Borough London NW1 6DX United Kingdom',
#        '1 15 Templeton Place Earl s Court Kensington and Chelsea London SW5 9NB United Kingdom',
#        '100 Queen s Gate Kensington and Chelsea London SW7 5AG United Kingdom',
#        '41 Great Cumberland Place Westminster Borough London W1H 7LG United Kingdom',
#        '52 54 Upper Richmond Road Wandsworth London SW15 2RN United Kingdom',
#        '2 Wallenberg Place Westminster Borough London W1H 7TN United Kingdom',
#        'Western Gateway Newham London E16 1FA United Kingdom',
#        'Mandeville Place Westminster Borough London W1U 2BE United Kingdom',
#        '134 George Street Westminster Borough London W1H 5DN United Kingdom',
#        '61 Lincoln s Inn Fields Camden London WC2A 3JW United Kingdom',
#        '10 Godliman Street City of London London EC4V 5AJ United Kingdom',
#        '40 trinity square City of London London EC3N 4DJ United Kingdom',
#        '2 Stanhope Row Park Lane Westminster Borough London W1J 7BS United Kingdom',
#        'Lowndes Street Kensington and Chelsea London SW1X 9ES United Kingdom',
#        '27 Devonshire Terrace Westminster Borough London W2 3DP United Kingdom',
#        'Scarsdale Place Kensington Kensington and Chelsea London W8 5SY United Kingdom',
#        '101 Buckingham Palace Road Westminster Borough London SW1W 0SJ United Kingdom',
#        '151 157 City Road Shoreditch Islington London EC1V 1JS United Kingdom',
#        'Tilling Road London NW2 1LP United Kingdom',
#        '7 Gracechurch Street City of London London EC3V 0DR United Kingdom',
#        '7 Western Gateway Royal Victoria Dock Newham London E16 1AA United Kingdom',
#        '140 Gloucester Road Kensington and Chelsea London SW7 4QH United Kingdom',
#        '81 Great Eastern Street Islington London EC2A 3HU United Kingdom',
#        '1 2 Serjeant s Inn Fleet Street City of London London EC4Y 1LL United Kingdom',
#        '225 Edgware Road Westminster Borough London W2 1JU United Kingdom',
#        '45 St Martin s Lane Westminster Borough London WC2N 4HX United Kingdom',
#        'George Street Westminster Borough London W1H 5BJ United Kingdom',
#        '20 Nevern Square Kensington and Chelsea London SW5 9PD United Kingdom',
#        '22 Portman Square Westminster Borough London W1H 7BG United Kingdom',
#        '626 Chiswick High St Chiswick London W4 5RY United Kingdom',
#        '49 53 New Road Tower Hamlets London E1 1HH United Kingdom',
#        '100 Cromwell Road Kensington and Chelsea London SW7 4ER United Kingdom',
#        '100 110 Euston Road Camden London NW1 2AJ United Kingdom',
#        '2 Caxton Street Westminster Borough London SW1H 0QW United Kingdom',
#        '41 54 Buckingham Gate Westminster Borough London SW1E 6AF United Kingdom',
#        '372 Strand Westminster Borough London WC2R 0JJ United Kingdom',
#        '7 8 Park Place Westminster Borough London SW1A 1LP United Kingdom',
#        '17 25 Sloane Street Knightsbridge Kensington and Chelsea London SW1X 9NU United Kingdom',
#        '44 Grosvenor Square Westminster Borough London W1K 2HP United Kingdom',
#        '265 Rotherhithe Street Southwark London SE16 5HW United Kingdom',
#        '88 Queens Gate Kensington and Chelsea London SW7 5AB United Kingdom',
#        'Poultry 27 City of London London EC2R 8AJ United Kingdom',
#        '6 Holywell Lane Hackney London EC2A 3ET United Kingdom',
#        '230 A Mile End Road Tower Hamlets London E1 4LJ United Kingdom',
#        '5 Fairmont Avenue Canary Wharf Tower Hamlets London E14 9JB United Kingdom',
#        '58 Shepherds Bush Green Hammersmith and Fulham London W12 8QE United Kingdom',
#        '150 Piccadilly Westminster Borough London W1J 9BR United Kingdom',
#        '1 Waterview Drive Greenwich London SE10 0TW United Kingdom',
#        '5 More London Place Tooley Street Southwark London SE1 2BY United Kingdom',
#        'Bloomsbury Way Camden London WC1A 2SD United Kingdom',
#        '26 28 Trebovir Rd Kensington and Chelsea London SW5 9NJ United Kingdom',
#        'Carlos Place Westminster Borough London W1K 2AL United Kingdom',
#        '22 28 Broadway Westminster Borough London SW1H 0BH United Kingdom',
#        '71 Vincent Square Westminster Borough London SW1P 2PA United Kingdom',
#        '146 Praed Street Westminster Borough London W2 1EE United Kingdom',
#        '160 Cromwell Road Kensington Kensington and Chelsea London SW5 0TL United Kingdom',
#        '199 206 High Holborn Camden London WC1V 7BD United Kingdom',
#        'St Katherines Way Tower Hamlets London E1W 1LD United Kingdom',
#        '22 Hertsmere Road Tower Hamlets London E14 4ED United Kingdom',
#        'Sloane Square Kensington and Chelsea London SW1W 8EG United Kingdom',
#        '2 4 Boundary Street Hackney London E2 7DD United Kingdom',
#        '130 Tottenham Court Road Camden London W1T 5AY United Kingdom',
#        '55 61 Westbourne Terrace Westminster Borough London W2 3UY United Kingdom',
#        '104 Bayswater Rd Westminster Borough London W2 3HL United Kingdom',
#        'Belgrove Street Camden London WC1H 8AB United Kingdom',
#        '31 Great Cumberland Place Westminster Borough London W1H 7TA United Kingdom',
#        'Lancaster Gate Westminster Borough London W2 3LG United Kingdom',
#        'The Strand Westminster Borough London WC2N 5HX United Kingdom',
#        'Epping Forest 30 Oak Hill London IG8 9NY United Kingdom',
#        '6 Hercules Road Lambeth London SE1 7DP United Kingdom',
#        '284 To 302 Waterloo Road Southwark London SE1 8RQ United Kingdom',
#        '31 St Thomas Street Southwark London SE1 9QU United Kingdom',
#        '8 Northumberland Avenue Westminster Borough London WC2N 5BY United Kingdom',
#        '23 Mecklenburgh Square Camden London WC1N 2AD United Kingdom',
#        'Coopers Row City of London London EC3N 2BQ United Kingdom',
#        '35 Charles Street Mayfair Westminster Borough London W1J 5EB United Kingdom',
#        'Coram Street Camden London WC1N 1HT United Kingdom',
#        '84 King Street Hammersmith and Fulham London W6 0QW United Kingdom',
#        '40 Marsh Wall Tower Hamlets London E14 9TP United Kingdom',
#        '14 16 Craven Hill Lancaster Gate Westminster Borough London W2 3DU United Kingdom',
#        '37 Nottingham Place Westminster Borough London W1U 5LT United Kingdom',
#        '380 Kensington High Street Kensington and Chelsea London W14 8NL United Kingdom',
#        '2 Whitehall Court Westminster Borough London SW1A 2EJ United Kingdom',
#        '19 21 Penywern Road Kensington and Chelsea London SW5 9TT United Kingdom',
#        '144 Praed St Paddington Westminster Borough London W2 1HU United Kingdom',
#        '43 Worple Road Wimbledon London SW19 4JZ United Kingdom',
#        '350 Oxford Street Westminster Borough London W1C 1BY United Kingdom',
#        '368 370 Green Lanes London N4 1DA United Kingdom',
#        '49 50 St John s Square Islington London EC1V 4JJ United Kingdom',
#        'Grosvenor Square Westminster Borough London W1K 6JP United Kingdom',
#        '4 Portal Way Gypsy Corner A40 London W3 6RT United Kingdom',
#        'Excel 2 Festoon Way Royal Victoria Dock Newham London E16 1RH United Kingdom',
#        '5 Olympic Way Wembley Brent London HA9 0NP United Kingdom',
#        'Royal Victoria Dock Western Gateway Newham London E16 1AL United Kingdom',
#        '78 82 Westbourne Terrace Westminster Borough London W2 6QA United Kingdom',
#        'Euston Road Camden London NW1 2AR United Kingdom',
#        '51 Gloucester Terrace Westminster Borough London W2 3DQ United Kingdom',
#        '20 Lavington Street Southwark London SE1 0NZ United Kingdom',
#        '80 86 Belgrave Road Westminster Borough London SW1V 2BJ United Kingdom',
#        '57 59 Welbeck Street Westminster Borough London W1G 9BL United Kingdom',
#        '29 31 Gower Street Camden London WC1E 6HG United Kingdom',
#        '8 14 Talbot Sq Paddington Westminster Borough London W2 1TS United Kingdom',
#        '252 High Holborn Holborn Camden London WC1V 7EN United Kingdom',
#        '20 Mercer Street Covent Garden Camden London WC2H 9HD United Kingdom',
#        'Whitehall Place Westminster Borough London SW1A 2BD United Kingdom',
#        '108 Baker Street Westminster Borough London W1U 6LJ United Kingdom',
#        '18 21 Charterhouse Square Islington London EC1M 6AH United Kingdom',
#        '239 Vauxhall Bridge Road Westminster Borough London SW1V 1EQ United Kingdom',
#        'Tower Bridge Road Southwark London SE1 3UN United Kingdom',
#        'Peters Lane Cowcross Street Islington London EC1M 6DS United Kingdom',
#        '8 Pembridge Garden Kensington and Chelsea London W2 4DU United Kingdom',
#        '335 337 High Street Stratford Newham London E15 2TF United Kingdom',
#        '15 Montague St Bloomsbury Camden London WC1B 5BJ United Kingdom',
#        '10 West Temple Sheen London SW14 7RT United Kingdom',
#        '19 21 Gt Marlborough St Westminster Borough London W1F 7HL United Kingdom',
#        '81 103 Euston Street Camden London NW1 2EZ United Kingdom',
#        '3 Kingdom Street Sheldon Square Westminster Borough London W2 6BD United Kingdom',
#        'Manor Road London IG8 8AE United Kingdom',
#        '2 8 Great Suffolk Street Southwark London SE1 0UG United Kingdom',
#        '1 8 Russell Square Camden London WC1B 5BE United Kingdom',
#        '68 Regent Street West End Mayfair Westminster Borough London W1B 4DY United Kingdom',
#        '628 Western Avenue London W3 0TA United Kingdom',
#        'Carburton Street Westminster Borough London W1W 5EE United Kingdom',
#        '86 88 Clerkenwell Road Islington London EC1M 5RJ United Kingdom',
#        '53 Upper Street Islington London N1 0UY United Kingdom',
#        'Richmond Way Hammersmith and Fulham London W14 0AX United Kingdom',
#        '20 28 Bolsover Street Westminster Borough London W1W 5NB United Kingdom',
#        '14 15 Langham Place Westminster Borough London W1B 2QS United Kingdom',
#        '12 Osborn Street Aldgate East Tower Hamlets London E1 6TE United Kingdom',
#        '40 Liverpool Street City of London London EC2M 7QN United Kingdom',
#        '19 25 Granville Place Marble Arch Westminster Borough London W1H 6PA United Kingdom',
#        '56 57 Frith Street Westminster Borough London W1D 3JG United Kingdom',
#        '66 Knightsbridge Westminster Borough London SW1X 7LA United Kingdom',
#        '7 9 Copthall Avenue City of London London EC2R 7NJ United Kingdom',
#        '10b Chestnut Plaza Westfield Stratford City Olympic Park Newham London E20 1GL United Kingdom',
#        '291 Greenwich High Road Greenwich Greenwich London SE10 8NA United Kingdom',
#        '15 16 Prince Of Wales Terrace Kensington and Chelsea London W8 5PQ United Kingdom',
#        '78 84 Sussex Gardens Westminster Borough London W2 1UH United Kingdom',
#        '1 Suffolk Place Westminster Borough London SW1Y 4HX United Kingdom',
#        '117 Poplar High Street Tower Hamlets London E14 0AE United Kingdom',
#        '16 London Street Paddington Westminster Borough London W2 1HL United Kingdom',
#        '15 Cromwell Place Kensington and Chelsea London SW7 2LA United Kingdom',
#        '82 Gloucester Place Westminster Borough London W1U 6HN United Kingdom',
#        '4 Richmond Mews Westminster Borough London W1D 3DH United Kingdom',
#        '30 Jamestown Road Camden London NW1 7BY United Kingdom',
#        '2 5 Montague Street Bloomsbury Camden London WC1B 5BU United Kingdom',
#        '202 220 Cromwell Road Kensington and Chelsea London SW5 0SW United Kingdom',
#        'St James s Place Westminster Borough London SW1A 1NJ United Kingdom',
#        '19 New Bridge Street City of London London EC4V 6DB United Kingdom',
#        '3 Berkeley Street Westminster Borough London W1J 8NE United Kingdom',
#        '18 Lodge Road Near Baker Street And Marylebone Westminster Borough London NW8 7JT United Kingdom',
#        '5 Cavell Street Tower Hamlets London E1 2BP United Kingdom',
#        '1 Hamilton Place Park Lane Westminster Borough London W1J 7QY United Kingdom',
#        '153 Hammersmith Road Hammersmith and Fulham London W14 0QL United Kingdom',
#        'Bridges Court Road Battersea London SW11 3BE United Kingdom',
#        '60 Pentonville Road Islington London N1 9LA United Kingdom',
#        'No 1 Seething Lane City of London London EC3N 4AX United Kingdom',
#        '18 Albert Embankment Lambeth London SE1 7TJ United Kingdom',
#        'King William Walk Greenwich London SE10 9JW United Kingdom',
#        '336 337 Strand London Westminster Borough London WC2R 1HA United Kingdom',
#        '128 King Henry s Road Camden London NW3 3ST United Kingdom',
#        '39 Buckingham Palace Road Westminster Borough London SW1W 0PS United Kingdom',
#        '101 Knightsbridge Westminster Borough London SW1X 7RN United Kingdom',
#        '11 13 Bayley Street Bedford Square Camden London WC1B 3HD United Kingdom',
#        '75 Gower Street Camden London WC1E 6HJ United Kingdom',
#        '8 12 Manchester Street Westminster Borough London W1U 4DG United Kingdom',
#        '15 Seymour Street Westminster Borough London W1H 7JW United Kingdom',
#        '142 To 144 Warwick Way Victoria Westminster Borough London SW1V 4JE United Kingdom',
#        'Southampton Row Bloomsbury Camden London WC1B 4AR United Kingdom',
#        '142 Minories City of London London EC3N 1LS United Kingdom',
#        'Piccadilly Westminster Borough London W1J 7BX United Kingdom',
#        '35 Ixworth Place Kensington and Chelsea London SW3 3QX United Kingdom',
#        '7 11 Queensberry Place Kensington and Chelsea London SW7 2DL United Kingdom',
#        '10 Harrington Road Kensington and Chelsea London SW7 3ER United Kingdom',
#        '22 Park Lane Westminster Borough London W1K 1BE United Kingdom',
#        '69 Vincent Square Westminster Borough London SW1P 2PA United Kingdom',
#        '39 Coventry Street Westminster Borough London W1D 6BZ United Kingdom',
#        'Bond Street Mayfair Westminster Borough London W1S 2YF United Kingdom',
#        '26 Cadogan Gardens Kensington and Chelsea London SW3 2RP United Kingdom',
#        '22 25 Finsbury Square City Islington London EC2A 1DX United Kingdom',
#        '34 Lombard Road Battersea London SW11 3RF United Kingdom',
#        '2 Warrington Crescent Westminster Borough London W9 1ER United Kingdom',
#        '4 Broad Court Bow Street Covent Garden Westminster Borough London WC2B 5QZ United Kingdom',
#        '49 Gloucester Place Marble Arch Westminster Borough London W1U 8JE United Kingdom',
#        '41 Queens Gate Gardens Kensington and Chelsea London SW7 5NB United Kingdom',
#        '6 Frith Street Soho Westminster Borough London W1D 3JA United Kingdom',
#        '111 Cromwell Road Kensington and Chelsea London SW7 4DP United Kingdom',
#        '16 22 Great Russell Street Camden London WC1B 3NN United Kingdom',
#        '31 33 Argyle Street Camden London WC1H 8EP United Kingdom',
#        '11 Thurloe Place Knightsbridge Kensington and Chelsea London SW7 2RS United Kingdom',
#        'Imperial Road Hammersmith and Fulham London SW6 2GA United Kingdom',
#        '150 Bayswater Road Kensington and Chelsea London W2 4RT United Kingdom',
#        '50 Lancaster Gate Westminster Borough London W2 3NA United Kingdom',
#        '335 337 Old Street Hackney London EC1V 9LL United Kingdom',
#        'Whitcomb Street Trafalgar Square Westminster Borough London WC2H 7HG United Kingdom',
#        'Lancaster Terrace Westminster Borough London W2 2TY United Kingdom',
#        '30 Rathbone Street West End Westminster Borough London W1T 1LB United Kingdom',
#        '33 Albemarle Street Mayfair Westminster Borough London W1S 4BP United Kingdom',
#        '8 10 Queensberry Place Kensington and Chelsea London SW7 2EA United Kingdom',
#        'Strand Westminster Borough London WC2R 0EU United Kingdom',
#        'Cardington Street Euston Camden London NW1 2LP United Kingdom',
#        '10 Carlisle Street Westminster Borough London W1D 3BR United Kingdom',
#        '81 Jermyn Street Westminster Borough London SW1Y 6JF United Kingdom',
#        '21 Gower Street Camden London WC1E 6HG United Kingdom',
#        '31 36 Leicester Square Westminster Borough London WC2H 7LH United Kingdom',
#        '117 129 Cromwell Road Kensington and Chelsea London SW7 4DS United Kingdom',
#        '10 Beaufort Gardens Kensington and Chelsea London SW3 1PT United Kingdom',
#        '2 Spring Gardens Trafalgar Square Westminster Borough London SW1A 2TS United Kingdom',
#        '5 Threadneedle Street City of London London EC2R 8AY United Kingdom',
#        'One Ham Yard Westminster Borough London W1D 7DT United Kingdom',
#        '9 Knaresborough Place Kensington and Chelsea London SW5 0TP United Kingdom',
#        '25 Courtfield Gardens Kensington and Chelsea London SW5 0PG United Kingdom',
#        'Cadogan Place Kensington and Chelsea London SW1X 9PY United Kingdom',
#        '29 31 Draycott Place Kensington and Chelsea London SW3 2SH United Kingdom',
#        '66 Great Queen Street Covent Garden Camden London WC2B 5BX United Kingdom',
#        '30 John Islip St Westminster Borough London SW1P 4DD United Kingdom',
#        '6 Waterloo Place Westminster Borough London SW1Y 4AN United Kingdom',
#        '13 15 Gower Street Camden London WC1E 6HE United Kingdom',
#        '41 51 Inverness Terrace Westminster Borough London W2 3JN United Kingdom',
#        '68 86 Cromwell Road Kensington Kensington and Chelsea London SW7 5BT United Kingdom',
#        '20 Chesham Place Kensington and Chelsea London SW1X 8HQ United Kingdom',
#        '9 13 Bloomsbury Street Nr Covent Garden Camden London WC1B 3QD United Kingdom',
#        'Half Moon Street Westminster Borough London W1J 7BH United Kingdom',
#        '45 Park Lane Westminster Borough London W1K 1PN United Kingdom',
#        '9 11 Sydney Street Kensington and Chelsea London SW3 6PU United Kingdom',
#        '31 35 Langham Street Westminster Borough London W1W 6BU United Kingdom',
#        'Old Park Lane Westminster Borough London W1K 1LB United Kingdom',
#        '54 Queens Gate Kensington and Chelsea London SW7 5JW United Kingdom',
#        '52 56 Inverness Terrace Westminster Borough London W2 3LB United Kingdom',
#        '42 46 Chiswell Street City of London London EC1Y 4SB United Kingdom',
#        '12 Upper Woburn Place Camden London WC1H 0HX United Kingdom',
#        '113 Lambeth Rd Lambeth London SE1 7LS United Kingdom',
#        '214 High Street Acton London London W3 9NX United Kingdom',
#        '90 92 Lancaster Gate Westminster Borough London W2 3NR United Kingdom',
#        '39 40 Cleveland Square Westminster Borough London W2 6DA United Kingdom',
#        'King s Cross St Pancras International Station Pancras Road Camden London N1C 4TB United Kingdom',
#        '7 Montague Street Bloomsbury Camden London WC1B 5BP United Kingdom',
#        '35 39 St Georges Drive Westminster Borough London SW1V 4DG United Kingdom',
#        'Hanger Lane Ealing London W5 3HL United Kingdom',
#        '222 Marylebone Road Westminster Borough London NW1 6JQ United Kingdom',
#        '47 Welbeck Street Westminster Borough London W1G 8DN United Kingdom',
#        '109 113 Queen s Gate Kensington and Chelsea London SW7 5LR United Kingdom',
#        '53 59 Kilburn High Road Maida Vale London Camden London NW6 5SB United Kingdom',
#        '10 Bina Gardens South Kensington Kensington and Chelsea London SW5 0LA United Kingdom',
#        '26 42 Bond Street Ealing London W5 5AA United Kingdom',
#        '15 Beeston Place Westminster Borough London SW1W 0JW United Kingdom',
#        '17 18 Upper Woburn Place Camden London WC1H 0HT United Kingdom',
#        '60 Hyde Park gate Kensington and Chelsea London SW7 5BB United Kingdom',
#        '346 348 Edgware Road Westminster Borough London W2 1EA United Kingdom',
#        '4 Bryanston St Marble Arch Westminster Borough London W1H 7BY United Kingdom',
#        '54 Uxbridge Road Shepherds Bush Hammersmith and Fulham London W12 8LP United Kingdom',
#        '10 Palace Place Westminster Borough London SW1E 5BW United Kingdom',
#        '37 Eccleston Square Westminster Borough London SW1V 1PB United Kingdom',
#        '100 Vauxhall Walk Lambeth London SE11 5AL United Kingdom',
#        '116 Piccadilly Westminster Borough London W1J 7BJ United Kingdom',
#        '33 Roland Gardens Kensington and Chelsea London SW7 3PF United Kingdom',
#        '24 27 Bedford Place Bloomsbury Camden London WC1B 5JH United Kingdom',
#        'Albany Street London NW1 3UP United Kingdom',
#        '50 Berners Street Westminster Borough London W1T 3NG United Kingdom',
#        '2 Montagu Place Westminster Borough London W1H 2ER United Kingdom',
#        '30 Portman Square Westminster Borough London W1H 7BH United Kingdom',
#        '10 Wardour Street Leicester Square Westminster Borough London W1D 6QF United Kingdom',
#        '19 Brent Street Brent Cross London NW4 2EU United Kingdom',
#        '1 Kensington Court Kensington and Chelsea London W8 5DL United Kingdom',
#        'Hamilton Place Park Lane Westminster Borough London W1J 7DR United Kingdom',
#        '33 Beaufort Gardens Kensington and Chelsea London SW3 1PP United Kingdom',
#        '18 30 Lexham Gardens Kensington and Chelsea London W8 5JE United Kingdom',
#        '20 Pembridge Gardens Kensington and Chelsea London W2 4DU United Kingdom',
#        '53 61 Southwark Bridge Road Southwark London SE1 9HH United Kingdom',
#        '45 Curtain Road Hackney London EC2A 4PJ United Kingdom',
#        '8 Balderton Street Brown Hart Gardens Westminster Borough London W1K 6TF United Kingdom',
#        'Western Avenue Ealing London W5 1HG United Kingdom',
#        'London County Hall Westminster Bridge Road Lambeth London SE1 7PB United Kingdom',
#        '14 Henrietta Street Westminster Borough London WC2E 8QH United Kingdom',
#        'Park Lane Westminster Borough London W1K 7TN United Kingdom',
#        '10 Pepys Street City of London London EC3N 2NR United Kingdom',
#        '50 Great Cumberland Place Westminster Borough London W1H 7FD United Kingdom',
#        '27 33 Harrington Gardens Kensington and Chelsea London SW7 4JX United Kingdom',
#        '41 Buckingham Palace Road Westminster Borough London SW1W 0PS United Kingdom',
#        '1 Aldwych Westminster Borough London WC2B 4BZ United Kingdom',
#        '3 Devonshire Terrace Westminster Borough London W2 3DN United Kingdom',
#        '34 37 Bedford Place Bloomsbury Camden London WC1B 5JR United Kingdom',
#        '407 Goldhawk Rd Chiswick London W6 0SA United Kingdom',
#        '225 Ladbroke Grove Kensington and Chelsea London W10 6HQ United Kingdom',
#        '140 Park Lane Westminster Borough London W1K 7AA United Kingdom',
#        '124 Clerkenwell Rd Camden London EC1R 5DJ United Kingdom',
#        '39 40 Bedford Place Bloomsbury Camden London WC1B 5JT United Kingdom',
#        '28 30 Seymour Street Westminster Borough London W1H 7JB United Kingdom',
#        '22 Stanley Gardens Kensington and Chelsea London W11 2NG United Kingdom',
#        '26 33 Queens Gardens Westminster Borough London W2 3BE United Kingdom',
#        '7 9 High Street Kensington Kensington and Chelsea London W8 5NP United Kingdom',
#        '15 17 Charlotte Street Hotel Westminster Borough London W1T 1RJ United Kingdom',
#        'Lancaster Terrace Hyde Park Westminster Borough London W2 3PF United Kingdom',
#        '3 Westbourne Terrace Lancaster Gate Westminster Borough London W2 3UL United Kingdom',
#        '86 Park Lane Westminster Borough London W1K 7TN United Kingdom',
#        '111 Westminster Bridge Road Lambeth London SE1 7JD United Kingdom',
#        '53 Park Lane Westminster Borough London W1K 1QA United Kingdom',
#        'Basil Street Knightsbridge Kensington and Chelsea London SW3 1AT United Kingdom',
#        '46 Westferry Circus Tower Hamlets London E14 8RS United Kingdom',
#        '17 Nottingham Place Westminster Borough London W1U 5LG United Kingdom',
#        '20 Warwick Street Westminster Borough London W1B 5NF United Kingdom',
#        '2 Sylvester Path Hackney London E8 1EN United Kingdom',
#        '147 Cromwell Road Kensington and Chelsea London SW5 0TH United Kingdom',
#        '8 18 London Bridge St Southwark London SE1 9SG United Kingdom',
#        '71 79 Southwark Street Southwark London SE1 0JA United Kingdom',
#        '11 Cadogan Gardens Sloane Square Kensington and Chelsea London SW3 2RJ United Kingdom',
#        '24 Egerton Gardens Kensington and Chelsea London SW3 2DB United Kingdom',
#        'Buckingham Gate Westminster Borough London SW1E 6AF United Kingdom',
#        'Wilton Place Knightsbridge Westminster Borough London SW1X 7RL United Kingdom',
#        'Halkin Street Westminster Borough London SW1X 7DJ United Kingdom',
#        '39 40 Dorset Square Hotel Westminster Borough London NW1 6QN United Kingdom',
#        '41 43 Brook Street Westminster Borough London W1K 4HJ United Kingdom',
#        '82 Dalston Lane Hackney London E8 3AH United Kingdom',
#        '17 19 Egerton Terrace Knightsbridge Kensington and Chelsea London SW3 2BX United Kingdom',
#        '181 Tooley Street Southwark London SE1 2JR United Kingdom',
#        '21 Avonmore Road Kensington Hammersmith and Fulham London W14 8RP United Kingdom',
#        '35 St James s Place Westminster Borough London SW1A 1NY United Kingdom',
#        '10 Monmouth Street Camden London WC2H 9HB United Kingdom',
#        '11 Knightsbridge Westminster Borough London SW1X 7LY United Kingdom',
#        'Hyde Park Corner Westminster Borough London SW1X 7TA United Kingdom'],
#       dtype=object)

# %% [markdown]
# В случае с Великобританией видим, что город в адресе отделён от страны почтовым индексом, причём представлен только Лондон

# %%
hotels['hotel_city'] = hotels.apply(lambda x: x['hotel_address'].split()[-5] 
    if x['hotel_country'] == 'United Kingdom' else x['hotel_address']\
        .split()[-2], axis=1)
print(hotels['hotel_city'].unique())

# Модифицируем данные в test
test['hotel_city'] = test.apply(lambda x: x['hotel_address'].split()[-5] 
    if x['hotel_country'] == 'United Kingdom' else x['hotel_address']\
        .split()[-2], axis=1)
# Out:
# ['London' 'Paris' 'Amsterdam' 'Milan' 'Vienna' 'Barcelona']

# %%
hotels_loc = hotels.groupby(by=['hotel_country', 'hotel_city'])\
    ['hotel_address'].nunique().reset_index()
print('Train data')
display(hotels_loc)

test_loc = test.groupby(by=['hotel_country', 'hotel_city'])\
    ['hotel_address'].nunique().reset_index()
print('Test data')
display(test_loc)
# Out:
# Train data
#     hotel_country hotel_city  hotel_address
# 0         Austria     Vienna            158
# 1          France      Paris            458
# 2           Italy      Milan            162
# 3     Netherlands  Amsterdam            105
# 4           Spain  Barcelona            211
# 5  United Kingdom     London            399
# Test data
#     hotel_country hotel_city  hotel_address
# 0         Austria     Vienna            158
# 1          France      Paris            458
# 2           Italy      Milan            162
# 3     Netherlands  Amsterdam            105
# 4           Spain  Barcelona            211
# 5  United Kingdom     London            399

# %% [markdown]
# Мы видим, что из каждой страны представлено по одному городу. Причём и в обучающей и в тестовой выборках представлены одинаковые отели.

# %% [markdown]
# **Note:**
# - 17 из 1493 отелей не имеют географических координат
# - Имеющийся набор данных можно расширить координатами центров городов и соотнести с городами, извлекаемыми из адреса
# - Исходя из координат центра города, а также широты и долготы расположения отеля, можно извлечь расстояние от отеля до центра города
# - Пропуски в координатах отелей можно заполнить медианным значением расстояния от центра до отеля

# %% [markdown]
# ### Посмотрим на взаимосвязь числовых признаков

# %%
sns.pairplot(hotels, corner=True)

# %%
# Убираем предупреждения
import warnings
warnings.filterwarnings("ignore")

# Строим корреляционные графики
fig, (pearson_axes, spearmen_axes) = plt.subplots(2,1, figsize=(12,8));
sns.heatmap(hotels.corr(), vmin=-1, vmax=1, annot=True, ax=pearson_axes);
sns.heatmap(hotels.corr(method='spearman'), vmin=-1, vmax=1,\
    annot=True, ax=spearmen_axes);
# Настраиваем графики
pearson_axes.set_title('Корреляция по Пирсону');
pearson_axes.set_xticks([])
spearmen_axes.set_title('Корреляция по Спирману');

# %% [markdown]
# **Correlation Notes:**
# - Наблюдается сильная скоррелированность 'total_number_of_reviews' и 'additional_number_of_scoring'. При этом связь обоих параметров с 'review_score' почти отсутствует.
# - Наблюдается обратная взаимосвязь 'total_positive_words_count' и 'total_negative_words_count'. Возможно, имеет смысл ввести соотношение количества слов позитивного/негативного отзывов.
# - С увеличением количества отзывов, которые оставил рецензент нелинейно уменьшается количество слов в каждом отзыве.
# - Наблюдается прямая связь количества слов в положительном отзыве к выставленной оценке и обратная связь количества слов в отрицательном отзыве к выставленной оценке
# - Средняя оценка отеля и оценка в отзыве также скоррелированы
# - Неожиданно наблюдать корреляцию широты (прямая) и долготы (обратная) расположения отеля и количества оценок без отзывов. Имеет смысл проанализировать детальнее эту взаимосвязь.
